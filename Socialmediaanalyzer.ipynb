# %% [markdown]
# <a href="https://colab.research.google.com/github/gulrubab/Tutorconnect/blob/main/Socialmediaanalyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob
# !pip install pandas

# %%
import pandas as pd
from textblob import TextBlob

# %%
def get_sentiment(text):
    analysis = TextBlob(text)

    if analysis.sentiment.polarity > 0:
        return "Positive 😀"
    elif analysis.sentiment.polarity == 0:
        return "Neutral 😐"
    else:
        return "Negative 😡"

# %%
posts = []

n = int(input("How many social media posts do you want to analyze? "))

for i in range(n):
    text = input(f"Enter post {i+1}: ")
    posts.append(text)

posts

# %%
df = pd.DataFrame(posts, columns=["Post"])

df["Sentiment"] = df["Post"].apply(get_sentiment)

df

# %%
import matplotlib.pyplot as plt

df["Sentiment"].value_counts().plot(kind="bar")

plt.title("Sentiment Analysis Results")
plt.xlabel("Sentiment")
plt.ylabel("Number of Posts")

plt.show()

# %%
sentiment_count = df["Sentiment"].value_counts()

print("Sentiment Summary:")
print(sentiment_count)
